# %% [markdown]
# # Package import

# %%
import os
import pandas as pd
from datetime import datetime
from icalendar import Calendar, Event
import ics

# %% [markdown]
# # Calander Export

# %%
group_id = "ZICSS1-1211"

# %%
Classes = pd.read_csv(f"schedules/{group_id}.csv", encoding="UTF-8")

# %%
if not os.path.exists("Calanders"):
    os.makedirs("Calanders", exist_ok=True)

# %%
cal = Calendar()
Calendar["dtstart"] = "20260223T000000"
Calendar["dtend"] = "20260903T000000"
Calendar["summary"] = f"schedu;e of the {group_id} group. "

# %%
cf = open(f"Calanders/{group_id}.ics", "w", encoding="UTF-8")

# %%
for x, row in Classes.iterrows():
    event = Event()
    event["dtstart"] = "TZID=Europe/Warsaw:" + row["Termin"].replace("-", "")+row["Start time"].replace(":", " "+"00")
    event["dtend"] = "TZID=Europe/Warsaw:" + row["Termin"].replace("-", "")+row["End time"].replace(":", " "+"00")

    event.name = f"{row['Przedmiot']} ({row['Typ']})"

    start_datetime = datetime.strptime(
        f"{row['Termin']} 08:00",
        "%Y-%m-%d %H:%M"
    )

    end_datetime = datetime.strptime(
        f"{row['Termin']} 09:30",
        "%Y-%m-%d %H:%M"
    )

    event.begin = start_datetime
    event.end = end_datetime

    event.location = row['Sala']

    event.description = (
        f"Nauczyciel: {row['Nauczyciel']}\n"
        f"Day: {row['Day']}"
    )

    cal.events.add(event)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\241956\Web Scraper\WebScraper\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 3
# ...

# %%
with open(f"Calendars/{group_id}.ics", "w", encoding="utf-8") as f:
    f.writelines(cal)

# %%
cf.close
# Out:
# <function TextIOWrapper.close()>
